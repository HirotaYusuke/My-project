# %% [markdown]
# ## Oputunaを用いて，LightGBMのベイズ最適化
#
# - Optunaのstudyを使用
# - [Oputunaのgithub](https://github.com/optuna/optuna-examples/blob/main/lightgbm/lightgbm_integration.py)を参考にコーディング

# %%
"""
Optuna example that demonstrates a pruner for LightGBM.
In this example, we optimize the validation accuracy of cancer detection using LightGBM.
We optimize both the choice of booster model and their hyperparameters. Throughout
training of models, a pruner observes intermediate results and stop unpromising trials.
You can run this example as follows:
    $ python lightgbm_integration.py
"""
# Out:
# '\nOptuna example that demonstrates a pruner for LightGBM.\nIn this example, we optimize the validation accuracy of cancer detection using LightGBM.\nWe optimize both the choice of booster model and their hyperparameters. Throughout\ntraining of models, a pruner observes intermediate results and stop unpromising trials.\nYou can run this example as follows:\n    $ python lightgbm_integration.py\n'

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import math
import urllib.request
import time

import scipy
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_squared_error, r2_score

import lightgbm as lgb

# %%
import optuna
import optuna.integration.lightgbm as lgb_tune
from lightgbm import early_stopping
from lightgbm import log_evaluation
from sklearn.model_selection import KFold

# %%
df = pd.read_csv('..//Data-science//data//boston.csv')

X = df[['INDUS', 'RM', 'TAX', 'PTRATIO', 'LSTAT']]
y = df['house prices']

# 標準化
X = pd.DataFrame(scipy.stats.zscore(X),index=X.index, columns=X.columns)

# %%
# 学習データ，検証データに分割
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2, shuffle=True, random_state=123)
X_train,X_valid,y_train,y_valid = train_test_split(X_train,y_train,test_size=0.2, shuffle=True, random_state=123)

# LightGBM には ndarray にすると良い
X_train = X_train.values
X_valid = X_valid.values
X_test = X_test.values

y_train = y_train.values
y_valid = y_valid.values
y_test = y_test.values

# %%
# LightGBM用にデータ変換
trains = lgb.Dataset(X_train, label=y_train, free_raw_data=False)
valids = lgb.Dataset(X_valid, label=y_valid, free_raw_data=False)

# %% [markdown]
# ### ハイパーパラメータについて
# #### suggest_float または suggest_int でパラメータの探索範囲を設定する(最大値，最小値)
# #### suggest_int は整数のみ探索

# %%
def objective(trial):

    # ハイパーパラメータの設定
    param = {
        "objective": "regression",
        "metric": "rmse",
        "verbosity": -1,
        "boosting_type": "gbdt",
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 1.0),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.4, 1.0),
        "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
    }

    # 学習
    gbm = lgb.train(param, trains)

    # 予測
    preds = gbm.predict(X_valid)
    # 精度の算出
    rmse = np.sqrt(mean_squared_error(y_valid, preds))

    return rmse

# %%
if __name__ == "__main__":
    # oputuna による最適化
    study = optuna.create_study(direction="minimize")
    # 探索数(試行数)を指定する場合
    study.optimize(objective, n_trials=1000)
    # 探索時間を指定する場合
    #study.optimize(objective, timeout=60)

    print("Number of finished trials: {}".format(len(study.trials)))

    print("Best trial:")

    print("  Value: {}".format(study.best_trial.value))

    print("  Params: ")

    tuned_params = {}
    for key, value in study.best_trial.params.items():
        #print("    {}: {}".format(key, value))
        tuned_params[key] = value

    print(tuned_params)
    
    #print(study.best_trial.value)
# Out:
# [I 2021-12-29 17:33:27,528] A new study created in memory with name: no-name-bfba6c04-4434-4107-afb0-77e15b3afe5a
# [I 2021-12-29 17:33:27,673] Trial 0 finished with value: 6.005932946104612 and parameters: {'lambda_l1': 2.5896660014843876e-07, 'lambda_l2': 0.6839056915417362, 'num_leaves': 239, 'feature_fraction': 0.6850250448643385, 'bagging_fraction': 0.8296000316748228, 'bagging_freq': 6, 'min_child_samples': 61}. Best is trial 0 with value: 6.005932946104612.
# [I 2021-12-29 17:33:27,802] Trial 1 finished with value: 6.6848775435130054 and parameters: {'lambda_l1': 0.0007053949846991518, 'lambda_l2': 9.688976037773749e-05, 'num_leaves': 55, 'feature_fraction': 0.8509881360287996, 'bagging_fraction': 0.7096794105632367, 'bagging_freq': 6, 'min_child_samples': 74}. Best is trial 0 with value: 6.005932946104612.
# [I 2021-12-29 17:33:27,853] Trial 2 finished with value: 5.161678992196041 and parameters: {'lambda_l1': 1.470657623350737e-07, 'lambda_l2': 3.574278977163836e-08, 'num_leaves': 151, 'feature_fraction': 0.6287375012654628, 'bagging_fraction': 0.5574682534836709, 'bagging_freq': 6, 'min_child_samples': 28}. Best is trial 2 with value: 5.161678992196041.
# [I 2021-12-29 17:33:27,930] Trial 3 finished with value: 4.970061184322361 and parameters: {'lambda_l1': 1.8810745021325759, 'lambda_l2': 0.00021073962431518214, 'num_leaves': 151, 'feature_fraction': 0.5199689497563251, 'bagging_fraction': 0.4888257710630678, 'bagging_freq': 4, 'min_child_samples': 21}. Best is trial 3 with value: 4.970061184322361.
# [I 2021-12-29 17:33:28,051] Trial 4 finished with value: 6.369789156438058 and parameters: {'lambda_l1': 1.5814673485447196e-06, 'lambda_l2': 8.60783961044376e-06, 'num_leaves': 35, 'feature_fraction': 0.7098801454866086, 'bagging_fraction': 0.6759891512148627, 'bagging_freq': 1, 'min_child_samples': 63}. Best is trial 3 with value: 4.970061184322361.
# [I 2021-12-29 17:33:28,145] Trial 5 finished with value: 6.407712072646729 and parameters: {'lambda_l1': 0.03714129079916655, 'lambda_l2': 0.0038826077276564487, 'num_leaves': 113, 'feature_fraction': 0.43291836659543503, 'bagging_fraction': 0.746166569426238, 'bagging_freq': 7, 'min_child_samples': 62}. Best is trial 3 with value: 4.970061184322361.
# [I 2021-12-29 17:33:28,206] Trial 6 finished with value: 7.400649278999865 and parameters: {'lambda_l1': 0.208687887992229, 'lambda_l2': 1.856873822449884e-06, 'num_leaves': 74, 'feature_fraction': 0.7151922650785045, 'bagging_fraction': 0.659672553038511, 'bagging_freq': 4, 'min_child_samples': 95}. Best is trial 3 with value: 4.970061184322361.
# [I 2021-12-29 17:33:28,304] Trial 7 finished with value: 5.642897751698511 and parameters: {'lambda_l1': 0.008501128739536462, 'lambda_l2': 0.00048310853003257214, 'num_leaves': 164, 'feature_fraction': 0.9391129804785135, 'bagging_fraction': 0.6828554091913059, 'bagging_freq': 7, 'min_child_samples': 45}. Best is trial 3 with value: 4.970061184322361.
# [I 2021-12-29 17:33:28,378] Trial 8 finished with value: 5.379670294415462 and parameters: {'lambda_l1': 0.0006461405138319051, 'lambda_l2': 0.1435703296790598, 'num_leaves': 102, 'feature_fraction': 0.9694346732297059, 'bagging_fraction': 0.5927549960107981, 'bagging_freq': 3, 'min_child_samples': 37}. Best is trial 3 with value: 4.970061184322361.
# [I 2021-12-29 17:33:28,456] Trial 9 finished with value: 5.796310781448062 and parameters: {'lambda_l1': 6.434480428919121e-06, 'lambda_l2': 4.624234443601592e-06, 'num_leaves': 230, 'feature_fraction': 0.46538017936965154, 'bagging_fraction': 0.5566342289801349, 'bagging_freq': 2, 'min_child_samples': 35}. Best is trial 3 with value: 4.970061184322361.
# [I 2021-12-29 17:33:28,537] Trial 10 finished with value: 4.26395723862913 and parameters: {'lambda_l1': 2.334706275423511, 'lambda_l2': 0.014045739025685304, 'num_leaves': 5, 'feature_fraction': 0.5517033522211275, 'bagging_fraction': 0.4323292482957098, 'bagging_freq': 4, 'min_child_samples': 6}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:28,590] Trial 11 finished with value: 4.497609048895467 and parameters: {'lambda_l1': 7.458732406514195, 'lambda_l2': 0.008005793582614431, 'num_leaves': 3, 'feature_fraction': 0.5451874274728277, 'bagging_fraction': 0.4258637413120636, 'bagging_freq': 4, 'min_child_samples': 7}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:28,665] Trial 12 finished with value: 4.640620643724089 and parameters: {'lambda_l1': 9.61893329684727, 'lambda_l2': 0.016883581563544588, 'num_leaves': 3, 'feature_fraction': 0.5761522541521293, 'bagging_fraction': 0.4279503042563909, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:28,746] Trial 13 finished with value: 4.571655526695734 and parameters: {'lambda_l1': 0.5172529568786662, 'lambda_l2': 6.519838603454774, 'num_leaves': 5, 'feature_fraction': 0.5543869830356666, 'bagging_fraction': 0.9428035455035716, 'bagging_freq': 5, 'min_child_samples': 5}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:28,853] Trial 14 finished with value: 5.169510850891177 and parameters: {'lambda_l1': 5.534527454205453, 'lambda_l2': 0.02471736868213226, 'num_leaves': 37, 'feature_fraction': 0.4029572063618232, 'bagging_fraction': 0.41626750992444594, 'bagging_freq': 3, 'min_child_samples': 18}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:28,934] Trial 15 finished with value: 4.49173518586409 and parameters: {'lambda_l1': 0.024285400172956852, 'lambda_l2': 0.0015159643926794463, 'num_leaves': 76, 'feature_fraction': 0.7982099699709081, 'bagging_fraction': 0.48772728790880987, 'bagging_freq': 5, 'min_child_samples': 16}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:29,365] Trial 16 finished with value: 4.648217350686418 and parameters: {'lambda_l1': 0.012481302279453418, 'lambda_l2': 0.29790342957435184, 'num_leaves': 84, 'feature_fraction': 0.7930512762409867, 'bagging_fraction': 0.5018956249184982, 'bagging_freq': 5, 'min_child_samples': 18}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:29,420] Trial 17 finished with value: 6.486061388194491 and parameters: {'lambda_l1': 4.266908269699777e-05, 'lambda_l2': 0.001180471555528491, 'num_leaves': 201, 'feature_fraction': 0.8058482607271095, 'bagging_fraction': 0.4892548783595481, 'bagging_freq': 5, 'min_child_samples': 48}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:29,512] Trial 18 finished with value: 4.971427130941609 and parameters: {'lambda_l1': 0.09826734428889962, 'lambda_l2': 4.206676941036852e-05, 'num_leaves': 52, 'feature_fraction': 0.8847371012518694, 'bagging_fraction': 0.611050141371196, 'bagging_freq': 2, 'min_child_samples': 29}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:29,758] Trial 19 finished with value: 6.7442425185726655 and parameters: {'lambda_l1': 0.0029381157335921187, 'lambda_l2': 4.753587771521956e-07, 'num_leaves': 76, 'feature_fraction': 0.6387113624759089, 'bagging_fraction': 0.829032123909177, 'bagging_freq': 5, 'min_child_samples': 89}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:29,821] Trial 20 finished with value: 4.6666517320380665 and parameters: {'lambda_l1': 3.602731391043688e-05, 'lambda_l2': 4.909730565429295, 'num_leaves': 127, 'feature_fraction': 0.7497016789385968, 'bagging_fraction': 0.512548461596067, 'bagging_freq': 4, 'min_child_samples': 17}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:29,915] Trial 21 finished with value: 4.868438210994411 and parameters: {'lambda_l1': 0.8852037675675093, 'lambda_l2': 0.005084945842061333, 'num_leaves': 23, 'feature_fraction': 0.49175980538973685, 'bagging_fraction': 0.4135090633833435, 'bagging_freq': 4, 'min_child_samples': 5}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:30,003] Trial 22 finished with value: 4.700705975825311 and parameters: {'lambda_l1': 0.10027112573807573, 'lambda_l2': 0.03756406100249992, 'num_leaves': 20, 'feature_fraction': 0.6139155399374174, 'bagging_fraction': 0.4595715940552977, 'bagging_freq': 4, 'min_child_samples': 12}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:30,523] Trial 23 finished with value: 5.430812063017962 and parameters: {'lambda_l1': 1.7984738549619166, 'lambda_l2': 0.0021519984403233702, 'num_leaves': 54, 'feature_fraction': 0.546885410012207, 'bagging_fraction': 0.40115347145457475, 'bagging_freq': 3, 'min_child_samples': 25}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:30,594] Trial 24 finished with value: 4.398570179615646 and parameters: {'lambda_l1': 0.3712029517864843, 'lambda_l2': 0.11381088987768524, 'num_leaves': 6, 'feature_fraction': 0.669429158900101, 'bagging_fraction': 0.5527080594402275, 'bagging_freq': 5, 'min_child_samples': 11}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:30,666] Trial 25 finished with value: 5.682218366306639 and parameters: {'lambda_l1': 1.2042067054207368e-08, 'lambda_l2': 0.8947067109726528, 'num_leaves': 98, 'feature_fraction': 0.6616843434691914, 'bagging_fraction': 0.5487387543550251, 'bagging_freq': 6, 'min_child_samples': 37}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:30,771] Trial 26 finished with value: 4.614781162047716 and parameters: {'lambda_l1': 0.02026508331073298, 'lambda_l2': 0.10804189898031824, 'num_leaves': 32, 'feature_fraction': 0.7807324714125826, 'bagging_fraction': 0.6241216616718358, 'bagging_freq': 5, 'min_child_samples': 13}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:30,864] Trial 27 finished with value: 5.340204264423986 and parameters: {'lambda_l1': 0.0032684915206088526, 'lambda_l2': 0.0009850772946748932, 'num_leaves': 62, 'feature_fraction': 0.5990014620633701, 'bagging_fraction': 0.45799838070981425, 'bagging_freq': 5, 'min_child_samples': 25}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:30,954] Trial 28 finished with value: 4.489285943061862 and parameters: {'lambda_l1': 0.29221942470513523, 'lambda_l2': 0.0355675520903468, 'num_leaves': 18, 'feature_fraction': 0.8571817602875248, 'bagging_fraction': 0.5285988685703694, 'bagging_freq': 6, 'min_child_samples': 15}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:31,519] Trial 29 finished with value: 5.933760959866336 and parameters: {'lambda_l1': 0.3440051554100034, 'lambda_l2': 0.47177330234001635, 'num_leaves': 40, 'feature_fraction': 0.6759864553721268, 'bagging_fraction': 0.77381558470832, 'bagging_freq': 7, 'min_child_samples': 53}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:31,563] Trial 30 finished with value: 6.1094250326938 and parameters: {'lambda_l1': 0.09691505444458873, 'lambda_l2': 0.060945426585868316, 'num_leaves': 18, 'feature_fraction': 0.9094476173656915, 'bagging_fraction': 0.9451090862968038, 'bagging_freq': 6, 'min_child_samples': 73}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:31,656] Trial 31 finished with value: 4.294541135364677 and parameters: {'lambda_l1': 0.8580972857485357, 'lambda_l2': 0.01234026988261868, 'num_leaves': 18, 'feature_fraction': 0.8251805987281711, 'bagging_fraction': 0.5370724679339456, 'bagging_freq': 6, 'min_child_samples': 12}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:31,746] Trial 32 finished with value: 4.307000083268314 and parameters: {'lambda_l1': 1.8131279999790648, 'lambda_l2': 0.012074126261096942, 'num_leaves': 17, 'feature_fraction': 0.8562766314565897, 'bagging_fraction': 0.5355249469376695, 'bagging_freq': 6, 'min_child_samples': 11}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:31,848] Trial 33 finished with value: 4.414430936045875 and parameters: {'lambda_l1': 2.159333477333038, 'lambda_l2': 1.5165099539411113, 'num_leaves': 43, 'feature_fraction': 0.8387784684151623, 'bagging_fraction': 0.5857819162283727, 'bagging_freq': 6, 'min_child_samples': 11}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:31,933] Trial 34 finished with value: 5.047514351753157 and parameters: {'lambda_l1': 1.2105952582068764, 'lambda_l2': 0.00011488224852910074, 'num_leaves': 19, 'feature_fraction': 0.7468074040500379, 'bagging_fraction': 0.6455200657560942, 'bagging_freq': 7, 'min_child_samples': 31}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:31,985] Trial 35 finished with value: 5.174509686268795 and parameters: {'lambda_l1': 3.249125392713566, 'lambda_l2': 0.013421277965002736, 'num_leaves': 2, 'feature_fraction': 0.8364536117901556, 'bagging_fraction': 0.5728788106216531, 'bagging_freq': 6, 'min_child_samples': 25}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:32,389] Trial 36 finished with value: 4.530676494022775 and parameters: {'lambda_l1': 0.7665101014761634, 'lambda_l2': 4.010536891029708e-05, 'num_leaves': 29, 'feature_fraction': 0.9808641842470697, 'bagging_fraction': 0.4574933017730329, 'bagging_freq': 6, 'min_child_samples': 11}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:32,490] Trial 37 finished with value: 4.499813848297757 and parameters: {'lambda_l1': 0.07343931405816799, 'lambda_l2': 0.2426795563900246, 'num_leaves': 64, 'feature_fraction': 0.7310338796301932, 'bagging_fraction': 0.7128028348360804, 'bagging_freq': 7, 'min_child_samples': 21}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:32,581] Trial 38 finished with value: 6.13194227605883 and parameters: {'lambda_l1': 0.24462936494491055, 'lambda_l2': 1.5531144373720545, 'num_leaves': 186, 'feature_fraction': 0.8951841483148296, 'bagging_fraction': 0.5356173319439277, 'bagging_freq': 5, 'min_child_samples': 43}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:32,661] Trial 39 finished with value: 4.575150897569484 and parameters: {'lambda_l1': 0.003225848485520568, 'lambda_l2': 0.00040843419705217937, 'num_leaves': 45, 'feature_fraction': 0.9380789752354566, 'bagging_fraction': 0.62701354230115, 'bagging_freq': 6, 'min_child_samples': 21}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:32,815] Trial 40 finished with value: 4.515177785389039 and parameters: {'lambda_l1': 0.00014555612422864232, 'lambda_l2': 0.007410314801344384, 'num_leaves': 245, 'feature_fraction': 0.6852653260519803, 'bagging_fraction': 0.9924446421840615, 'bagging_freq': 6, 'min_child_samples': 10}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:32,909] Trial 41 finished with value: 4.408995445026711 and parameters: {'lambda_l1': 2.7575794557999225, 'lambda_l2': 1.3056560972855755, 'num_leaves': 16, 'feature_fraction': 0.8327108793094528, 'bagging_fraction': 0.5908370783896373, 'bagging_freq': 6, 'min_child_samples': 10}. Best is trial 10 with value: 4.26395723862913.
# [I 2021-12-29 17:33:33,006] Trial 42 finished with value: 4.245065295085159 and parameters: {'lambda_l1': 3.606408159955888, 'lambda_l2': 0.08814077929307208, 'num_leaves': 12, 'feature_fraction': 0.8579106244672663, 'bagging_fraction': 0.5831361254309714, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:33,179] Trial 43 finished with value: 4.256041153827644 and parameters: {'lambda_l1': 5.125672708012448, 'lambda_l2': 0.09085151747661188, 'num_leaves': 30, 'feature_fraction': 0.8654061198659547, 'bagging_fraction': 0.5607726481766866, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:33,264] Trial 44 finished with value: 4.294207356723783 and parameters: {'lambda_l1': 4.4505599095410675, 'lambda_l2': 0.08102902451300592, 'num_leaves': 27, 'feature_fraction': 0.8702707697841194, 'bagging_fraction': 0.4741071650085457, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:33,378] Trial 45 finished with value: 4.576854922019699 and parameters: {'lambda_l1': 8.038883618673585, 'lambda_l2': 0.06411935049300896, 'num_leaves': 31, 'feature_fraction': 0.9216908919271586, 'bagging_fraction': 0.4682769882786405, 'bagging_freq': 7, 'min_child_samples': 7}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:33,480] Trial 46 finished with value: 4.260930010706013 and parameters: {'lambda_l1': 4.675713138991285, 'lambda_l2': 0.0035399142660416587, 'num_leaves': 61, 'feature_fraction': 0.8795159125192952, 'bagging_fraction': 0.4357730777586481, 'bagging_freq': 7, 'min_child_samples': 6}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:33,574] Trial 47 finished with value: 4.324037668945381 and parameters: {'lambda_l1': 9.946681982112713, 'lambda_l2': 0.0034047829516765963, 'num_leaves': 95, 'feature_fraction': 0.8766505480607731, 'bagging_fraction': 0.4319845824813191, 'bagging_freq': 7, 'min_child_samples': 6}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:33,703] Trial 48 finished with value: 4.858331502691825 and parameters: {'lambda_l1': 5.769435561341056e-07, 'lambda_l2': 0.16960572173062644, 'num_leaves': 50, 'feature_fraction': 0.9938887706461342, 'bagging_fraction': 0.47945409897949737, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:33,787] Trial 49 finished with value: 4.91317915932761 and parameters: {'lambda_l1': 4.3011333897096025, 'lambda_l2': 1.677801239332849e-08, 'num_leaves': 64, 'feature_fraction': 0.9418946741558848, 'bagging_fraction': 0.5173263118005558, 'bagging_freq': 7, 'min_child_samples': 22}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:33,878] Trial 50 finished with value: 24.17669518739981 and parameters: {'lambda_l1': 4.339804495756841, 'lambda_l2': 0.5603090718080797, 'num_leaves': 132, 'feature_fraction': 0.9580457279066971, 'bagging_fraction': 0.4491461228530481, 'bagging_freq': 7, 'min_child_samples': 75}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:33,977] Trial 51 finished with value: 4.442868770837845 and parameters: {'lambda_l1': 0.7573845048750848, 'lambda_l2': 0.023647175760482777, 'num_leaves': 10, 'feature_fraction': 0.8127151687257793, 'bagging_fraction': 0.5032183465473146, 'bagging_freq': 7, 'min_child_samples': 15}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:34,113] Trial 52 finished with value: 4.322957643456184 and parameters: {'lambda_l1': 1.3526942089430989, 'lambda_l2': 0.00366390503544881, 'num_leaves': 29, 'feature_fraction': 0.8637325517084147, 'bagging_fraction': 0.44039320020523315, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:34,195] Trial 53 finished with value: 4.584495691813649 and parameters: {'lambda_l1': 9.998553507434407, 'lambda_l2': 0.06920913087122005, 'num_leaves': 38, 'feature_fraction': 0.760611839350438, 'bagging_fraction': 0.5640912360688608, 'bagging_freq': 7, 'min_child_samples': 18}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:34,299] Trial 54 finished with value: 4.47881096044617 and parameters: {'lambda_l1': 3.7210385967523183, 'lambda_l2': 0.0006418965672004342, 'num_leaves': 25, 'feature_fraction': 0.9084938326651703, 'bagging_fraction': 0.49603734792024123, 'bagging_freq': 7, 'min_child_samples': 8}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:34,391] Trial 55 finished with value: 4.417378532842713 and parameters: {'lambda_l1': 0.5658761724038835, 'lambda_l2': 3.495399869456276, 'num_leaves': 10, 'feature_fraction': 0.8225120847125085, 'bagging_fraction': 0.6742393971850433, 'bagging_freq': 2, 'min_child_samples': 14}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:34,483] Trial 56 finished with value: 4.882319380625249 and parameters: {'lambda_l1': 0.12603654904475217, 'lambda_l2': 0.010598619957374274, 'num_leaves': 85, 'feature_fraction': 0.7761264574955808, 'bagging_fraction': 0.40242491799701746, 'bagging_freq': 1, 'min_child_samples': 19}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:34,612] Trial 57 finished with value: 4.370512407631275 and parameters: {'lambda_l1': 0.05521704600684785, 'lambda_l2': 0.00021392641962309544, 'num_leaves': 46, 'feature_fraction': 0.889568537064472, 'bagging_fraction': 0.4297756887775343, 'bagging_freq': 4, 'min_child_samples': 8}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:34,821] Trial 58 finished with value: 4.60312315489428 and parameters: {'lambda_l1': 1.4983945105778884, 'lambda_l2': 0.027369116240525505, 'num_leaves': 57, 'feature_fraction': 0.5116616407665624, 'bagging_fraction': 0.5153589545653622, 'bagging_freq': 7, 'min_child_samples': 15}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:34,876] Trial 59 finished with value: 6.951057940010306 and parameters: {'lambda_l1': 0.21539641637377174, 'lambda_l2': 0.002556334631218514, 'num_leaves': 11, 'feature_fraction': 0.4484647213074003, 'bagging_fraction': 0.47466618898146784, 'bagging_freq': 3, 'min_child_samples': 58}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:34,955] Trial 60 finished with value: 5.595599162618187 and parameters: {'lambda_l1': 5.085992653918617, 'lambda_l2': 9.28958180247453e-08, 'num_leaves': 111, 'feature_fraction': 0.8780929989937399, 'bagging_fraction': 0.4918100050534172, 'bagging_freq': 7, 'min_child_samples': 33}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:36,162] Trial 61 finished with value: 4.317311263084884 and parameters: {'lambda_l1': 1.9028480607684333, 'lambda_l2': 0.013333446452752952, 'num_leaves': 35, 'feature_fraction': 0.8489542603264769, 'bagging_fraction': 0.5389957986180826, 'bagging_freq': 6, 'min_child_samples': 9}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:36,270] Trial 62 finished with value: 4.65483446939364 and parameters: {'lambda_l1': 0.7647272217191542, 'lambda_l2': 0.007568149610468367, 'num_leaves': 24, 'feature_fraction': 0.8642589772822916, 'bagging_fraction': 0.609376680932624, 'bagging_freq': 6, 'min_child_samples': 13}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:36,375] Trial 63 finished with value: 4.350480104106306 and parameters: {'lambda_l1': 1.9397972090111484, 'lambda_l2': 0.04247722387453761, 'num_leaves': 12, 'feature_fraction': 0.797338641358351, 'bagging_fraction': 0.5701197379174976, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:36,467] Trial 64 finished with value: 4.335503666534819 and parameters: {'lambda_l1': 4.9036903226485204, 'lambda_l2': 0.13177167794171704, 'num_leaves': 5, 'feature_fraction': 0.9336809386856578, 'bagging_fraction': 0.5325896266086922, 'bagging_freq': 6, 'min_child_samples': 9}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:36,573] Trial 65 finished with value: 4.390373613879892 and parameters: {'lambda_l1': 0.46048887299280017, 'lambda_l2': 0.3284213951635222, 'num_leaves': 24, 'feature_fraction': 0.8190078086043671, 'bagging_fraction': 0.5208611927129894, 'bagging_freq': 4, 'min_child_samples': 13}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:36,662] Trial 66 finished with value: 4.848731799957054 and parameters: {'lambda_l1': 2.5997193819379683, 'lambda_l2': 0.017863258492257374, 'num_leaves': 35, 'feature_fraction': 0.9044733772647153, 'bagging_fraction': 0.47765135194314884, 'bagging_freq': 7, 'min_child_samples': 18}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:36,756] Trial 67 finished with value: 4.767196710200855 and parameters: {'lambda_l1': 0.17133517818756536, 'lambda_l2': 0.001324329248484535, 'num_leaves': 15, 'feature_fraction': 0.7164239145328386, 'bagging_fraction': 0.5512218680043537, 'bagging_freq': 5, 'min_child_samples': 24}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:36,880] Trial 68 finished with value: 4.383371952744195 and parameters: {'lambda_l1': 0.9908701970629049, 'lambda_l2': 0.005355972628773039, 'num_leaves': 74, 'feature_fraction': 0.8547414646730046, 'bagging_fraction': 0.41817659652531786, 'bagging_freq': 6, 'min_child_samples': 8}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:37,157] Trial 69 finished with value: 4.60742985101698 and parameters: {'lambda_l1': 1.1181466979548448e-05, 'lambda_l2': 0.0963949877331824, 'num_leaves': 3, 'feature_fraction': 0.7862846208368709, 'bagging_fraction': 0.6029269499485341, 'bagging_freq': 3, 'min_child_samples': 12}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:37,203] Trial 70 finished with value: 5.559599223681024 and parameters: {'lambda_l1': 0.007874379083426345, 'lambda_l2': 0.21770893448579995, 'num_leaves': 52, 'feature_fraction': 0.5724426442596378, 'bagging_fraction': 0.4479219779040676, 'bagging_freq': 4, 'min_child_samples': 29}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:37,281] Trial 71 finished with value: 24.420473325584023 and parameters: {'lambda_l1': 1.8481404501346645, 'lambda_l2': 0.013904737779068494, 'num_leaves': 39, 'feature_fraction': 0.8450779030285136, 'bagging_fraction': 0.576580159484001, 'bagging_freq': 6, 'min_child_samples': 98}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:37,618] Trial 72 finished with value: 4.310224336400283 and parameters: {'lambda_l1': 6.602809585502706, 'lambda_l2': 0.03063356697265577, 'num_leaves': 33, 'feature_fraction': 0.880338542969813, 'bagging_fraction': 0.5409709349405146, 'bagging_freq': 6, 'min_child_samples': 10}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:38,502] Trial 73 finished with value: 4.498175716656406 and parameters: {'lambda_l1': 3.2145379451511062, 'lambda_l2': 0.04385859821323487, 'num_leaves': 26, 'feature_fraction': 0.8746813691425145, 'bagging_fraction': 0.6255343420873708, 'bagging_freq': 6, 'min_child_samples': 16}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:38,596] Trial 74 finished with value: 4.419768811937342 and parameters: {'lambda_l1': 6.528728947515206, 'lambda_l2': 0.030061387893152387, 'num_leaves': 18, 'feature_fraction': 0.9176674693192797, 'bagging_fraction': 0.5045345777808289, 'bagging_freq': 7, 'min_child_samples': 11}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:38,754] Trial 75 finished with value: 4.792661824135255 and parameters: {'lambda_l1': 0.4995327781196221, 'lambda_l2': 0.0018560945888128884, 'num_leaves': 42, 'feature_fraction': 0.9607608605998923, 'bagging_fraction': 0.6501975223769454, 'bagging_freq': 5, 'min_child_samples': 5}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:38,876] Trial 76 finished with value: 5.031141107431917 and parameters: {'lambda_l1': 1.0739595880296597, 'lambda_l2': 0.0049515907559114425, 'num_leaves': 214, 'feature_fraction': 0.4129249932161491, 'bagging_fraction': 0.5544019015756703, 'bagging_freq': 7, 'min_child_samples': 8}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:38,968] Trial 77 finished with value: 5.065254790578713 and parameters: {'lambda_l1': 5.969415586042268, 'lambda_l2': 0.07657732875214229, 'num_leaves': 160, 'feature_fraction': 0.8989244565601805, 'bagging_fraction': 0.4648596834429167, 'bagging_freq': 6, 'min_child_samples': 20}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:39,183] Trial 78 finished with value: 4.357658178369526 and parameters: {'lambda_l1': 0.0005916085449567163, 'lambda_l2': 0.4446178988834288, 'num_leaves': 59, 'feature_fraction': 0.8218227646214505, 'bagging_fraction': 0.7380329605711918, 'bagging_freq': 7, 'min_child_samples': 16}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:39,268] Trial 79 finished with value: 6.2612361142118695 and parameters: {'lambda_l1': 3.0649343021743802, 'lambda_l2': 0.020240922440078274, 'num_leaves': 47, 'feature_fraction': 0.6354671703577929, 'bagging_fraction': 0.8189726383603897, 'bagging_freq': 6, 'min_child_samples': 67}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:39,379] Trial 80 finished with value: 4.325498715927499 and parameters: {'lambda_l1': 0.29485265380099174, 'lambda_l2': 0.0075272429993707745, 'num_leaves': 31, 'feature_fraction': 0.8834230248582983, 'bagging_fraction': 0.5398103189187624, 'bagging_freq': 5, 'min_child_samples': 11}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:39,535] Trial 81 finished with value: 4.367524403143458 and parameters: {'lambda_l1': 1.5717385079200044, 'lambda_l2': 0.009489471708831802, 'num_leaves': 33, 'feature_fraction': 0.8450819104471717, 'bagging_fraction': 0.5338093607026475, 'bagging_freq': 6, 'min_child_samples': 9}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:39,640] Trial 82 finished with value: 4.276463332932575 and parameters: {'lambda_l1': 8.935139972935774, 'lambda_l2': 0.04776212445979245, 'num_leaves': 21, 'feature_fraction': 0.8595790652435934, 'bagging_fraction': 0.5765555502929082, 'bagging_freq': 6, 'min_child_samples': 7}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:39,771] Trial 83 finished with value: 4.3685796992972 and parameters: {'lambda_l1': 8.753873370215178, 'lambda_l2': 0.04858653122723292, 'num_leaves': 20, 'feature_fraction': 0.8296536434887779, 'bagging_fraction': 0.5828228348187133, 'bagging_freq': 7, 'min_child_samples': 7}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:39,879] Trial 84 finished with value: 4.475363241128874 and parameters: {'lambda_l1': 5.219950589729537, 'lambda_l2': 0.17330369966049444, 'num_leaves': 11, 'feature_fraction': 0.8621913298374004, 'bagging_fraction': 0.48638147401599735, 'bagging_freq': 6, 'min_child_samples': 13}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:39,963] Trial 85 finished with value: 5.579863071776523 and parameters: {'lambda_l1': 2.950518716083513e-08, 'lambda_l2': 0.10134287570228127, 'num_leaves': 8, 'feature_fraction': 0.9249451527493108, 'bagging_fraction': 0.5981750748181505, 'bagging_freq': 4, 'min_child_samples': 40}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:40,120] Trial 86 finished with value: 4.360369871064568 and parameters: {'lambda_l1': 3.267286641054648, 'lambda_l2': 0.6895493323818006, 'num_leaves': 22, 'feature_fraction': 0.8704265386681551, 'bagging_fraction': 0.5585040369149202, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:40,302] Trial 87 finished with value: 5.160153841098925 and parameters: {'lambda_l1': 0.7533963540666917, 'lambda_l2': 0.030800971195137066, 'num_leaves': 16, 'feature_fraction': 0.8056879233747899, 'bagging_fraction': 0.4388159823108429, 'bagging_freq': 7, 'min_child_samples': 23}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:40,374] Trial 88 finished with value: 5.016638933780876 and parameters: {'lambda_l1': 9.731088179166951, 'lambda_l2': 0.3086647000350813, 'num_leaves': 2, 'feature_fraction': 0.8906563917356463, 'bagging_fraction': 0.5077781467111324, 'bagging_freq': 6, 'min_child_samples': 10}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:40,585] Trial 89 finished with value: 4.381955105709864 and parameters: {'lambda_l1': 2.0715921065919063, 'lambda_l2': 0.0025401863985108856, 'num_leaves': 27, 'feature_fraction': 0.7648520382133354, 'bagging_fraction': 0.40545587467219146, 'bagging_freq': 5, 'min_child_samples': 7}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:40,680] Trial 90 finished with value: 23.526862458988546 and parameters: {'lambda_l1': 1.211001804772124, 'lambda_l2': 0.0008525400950971992, 'num_leaves': 68, 'feature_fraction': 0.9522579492068279, 'bagging_fraction': 0.45356042924469875, 'bagging_freq': 7, 'min_child_samples': 83}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:40,841] Trial 91 finished with value: 4.523593246784364 and parameters: {'lambda_l1': 2.3642503774335504, 'lambda_l2': 0.013769042577404196, 'num_leaves': 37, 'feature_fraction': 0.850279637036734, 'bagging_fraction': 0.5400479124401968, 'bagging_freq': 6, 'min_child_samples': 14}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:40,958] Trial 92 finished with value: 4.341484524339756 and parameters: {'lambda_l1': 6.413725851867109, 'lambda_l2': 0.0172517901962809, 'num_leaves': 35, 'feature_fraction': 0.8318103789949239, 'bagging_fraction': 0.5678260402856835, 'bagging_freq': 6, 'min_child_samples': 10}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:41,106] Trial 93 finished with value: 4.329869468433518 and parameters: {'lambda_l1': 4.053043846488783, 'lambda_l2': 0.06377070444058659, 'num_leaves': 29, 'feature_fraction': 0.846068441129401, 'bagging_fraction': 0.5267466436707353, 'bagging_freq': 6, 'min_child_samples': 8}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:41,235] Trial 94 finished with value: 4.4804684161005515 and parameters: {'lambda_l1': 0.48482295336395237, 'lambda_l2': 0.00475853980920498, 'num_leaves': 14, 'feature_fraction': 0.9129224557571178, 'bagging_fraction': 0.6380086777418614, 'bagging_freq': 7, 'min_child_samples': 12}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:41,371] Trial 95 finished with value: 4.591934598866648 and parameters: {'lambda_l1': 1.538240098666192, 'lambda_l2': 0.0109248702642801, 'num_leaves': 43, 'feature_fraction': 0.89203705647059, 'bagging_fraction': 0.5920933563957997, 'bagging_freq': 6, 'min_child_samples': 17}. Best is trial 42 with value: 4.245065295085159.
# [I 2021-12-29 17:33:41,519] Trial 96 finished with value: 4.105127894172081 and parameters: {'lambda_l1': 2.5837764092510445, 'lambda_l2': 0.021935052172184923, 'num_leaves': 22, 'feature_fraction': 0.8080153124724547, 'bagging_fraction': 0.5166637915509207, 'bagging_freq': 7, 'min_child_samples': 6}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:41,615] Trial 97 finished with value: 4.447842010273984 and parameters: {'lambda_l1': 5.928412810197515, 'lambda_l2': 0.024924564534034167, 'num_leaves': 8, 'feature_fraction': 0.8023831764652966, 'bagging_fraction': 0.4973978952736135, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:41,764] Trial 98 finished with value: 4.240234669933176 and parameters: {'lambda_l1': 0.9257089667339486, 'lambda_l2': 0.04538174121144477, 'num_leaves': 21, 'feature_fraction': 0.8670268153865012, 'bagging_fraction': 0.42448531989101224, 'bagging_freq': 7, 'min_child_samples': 7}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:41,913] Trial 99 finished with value: 4.4936886741059885 and parameters: {'lambda_l1': 0.17020987572015056, 'lambda_l2': 0.13303573384097306, 'num_leaves': 130, 'feature_fraction': 0.6562818633345942, 'bagging_fraction': 0.4725622517746575, 'bagging_freq': 7, 'min_child_samples': 7}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:42,059] Trial 100 finished with value: 4.806805609135174 and parameters: {'lambda_l1': 0.7628900662493314, 'lambda_l2': 0.050897777896614635, 'num_leaves': 21, 'feature_fraction': 0.8098302500037255, 'bagging_fraction': 0.41715019353373545, 'bagging_freq': 7, 'min_child_samples': 14}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:42,184] Trial 101 finished with value: 4.196683597584898 and parameters: {'lambda_l1': 2.9218325275653796, 'lambda_l2': 0.08803090518918635, 'num_leaves': 14, 'feature_fraction': 0.8670230410964007, 'bagging_fraction': 0.4382273729775961, 'bagging_freq': 7, 'min_child_samples': 10}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:42,301] Trial 102 finished with value: 4.184203324511017 and parameters: {'lambda_l1': 2.8720055371253883, 'lambda_l2': 0.19155268353142724, 'num_leaves': 14, 'feature_fraction': 0.8632735386949125, 'bagging_fraction': 0.429168054336357, 'bagging_freq': 7, 'min_child_samples': 6}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:42,460] Trial 103 finished with value: 4.314430498520537 and parameters: {'lambda_l1': 2.9302062166060288, 'lambda_l2': 0.2000940403361127, 'num_leaves': 13, 'feature_fraction': 0.866525689097197, 'bagging_fraction': 0.42127756236998243, 'bagging_freq': 7, 'min_child_samples': 7}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:42,632] Trial 104 finished with value: 4.251351998790695 and parameters: {'lambda_l1': 1.1301515636550528, 'lambda_l2': 2.2982491575645136, 'num_leaves': 7, 'feature_fraction': 0.8367098846307098, 'bagging_fraction': 0.4407652576675925, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:42,753] Trial 105 finished with value: 4.551028925464749 and parameters: {'lambda_l1': 3.971604263917632, 'lambda_l2': 9.629916745464184, 'num_leaves': 7, 'feature_fraction': 0.8349659620776559, 'bagging_fraction': 0.4452042164747025, 'bagging_freq': 7, 'min_child_samples': 6}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:42,933] Trial 106 finished with value: 4.9662279105287865 and parameters: {'lambda_l1': 0.3938224094401622, 'lambda_l2': 1.8695460296128257, 'num_leaves': 23, 'feature_fraction': 0.48078877727540437, 'bagging_fraction': 0.4397341889717464, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:43,747] Trial 107 finished with value: 4.433160297357498 and parameters: {'lambda_l1': 1.1997860423325721, 'lambda_l2': 0.8192612757604211, 'num_leaves': 142, 'feature_fraction': 0.896659583836514, 'bagging_fraction': 0.42902420827134846, 'bagging_freq': 7, 'min_child_samples': 9}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:43,868] Trial 108 finished with value: 4.944151836766438 and parameters: {'lambda_l1': 2.2156426241307985, 'lambda_l2': 4.0753769611755954, 'num_leaves': 2, 'feature_fraction': 0.8592175222867879, 'bagging_fraction': 0.4616656799472644, 'bagging_freq': 7, 'min_child_samples': 7}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:46,410] Trial 109 finished with value: 4.776146554620317 and parameters: {'lambda_l1': 9.88145378286133, 'lambda_l2': 2.4709388681165483, 'num_leaves': 14, 'feature_fraction': 0.9278814627897329, 'bagging_fraction': 0.4068860797992956, 'bagging_freq': 7, 'min_child_samples': 12}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:46,574] Trial 110 finished with value: 4.261529788405498 and parameters: {'lambda_l1': 0.5843052833581414, 'lambda_l2': 0.4183803196499775, 'num_leaves': 6, 'feature_fraction': 0.875010602039355, 'bagging_fraction': 0.4827554042737655, 'bagging_freq': 7, 'min_child_samples': 9}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:46,698] Trial 111 finished with value: 4.3154276281695285 and parameters: {'lambda_l1': 0.5728056536853758, 'lambda_l2': 0.397096147999584, 'num_leaves': 8, 'feature_fraction': 0.8727661736266679, 'bagging_fraction': 0.4324212506624955, 'bagging_freq': 7, 'min_child_samples': 9}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:46,889] Trial 112 finished with value: 4.59180809975214 and parameters: {'lambda_l1': 4.329022906594972, 'lambda_l2': 1.1605041032090513, 'num_leaves': 26, 'feature_fraction': 0.9067173552814454, 'bagging_fraction': 0.4817441182145562, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:47,219] Trial 113 finished with value: 4.238972629583812 and parameters: {'lambda_l1': 1.163250517107919, 'lambda_l2': 0.08787370023028286, 'num_leaves': 18, 'feature_fraction': 0.8398321907966575, 'bagging_fraction': 0.4576254523606736, 'bagging_freq': 7, 'min_child_samples': 7}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:47,327] Trial 114 finished with value: 4.796471575467724 and parameters: {'lambda_l1': 1.2482666346431215, 'lambda_l2': 0.23275311759771924, 'num_leaves': 17, 'feature_fraction': 0.8377833994963385, 'bagging_fraction': 0.4532361658813588, 'bagging_freq': 7, 'min_child_samples': 15}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:47,436] Trial 115 finished with value: 4.413803127175178 and parameters: {'lambda_l1': 0.04778327932547815, 'lambda_l2': 0.12072269927948309, 'num_leaves': 6, 'feature_fraction': 0.7886089487680072, 'bagging_fraction': 0.4642880595176681, 'bagging_freq': 7, 'min_child_samples': 11}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:47,613] Trial 116 finished with value: 4.26443792866182 and parameters: {'lambda_l1': 0.0001192204295581442, 'lambda_l2': 0.08584715454317486, 'num_leaves': 21, 'feature_fraction': 0.8203449146510812, 'bagging_fraction': 0.41816076564836496, 'bagging_freq': 7, 'min_child_samples': 7}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:47,723] Trial 117 finished with value: 4.50182239616964 and parameters: {'lambda_l1': 8.389143133680624e-05, 'lambda_l2': 0.6357742307752224, 'num_leaves': 13, 'feature_fraction': 0.8222221253353958, 'bagging_fraction': 0.42046482578753747, 'bagging_freq': 7, 'min_child_samples': 9}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:47,850] Trial 118 finished with value: 4.613098981241342 and parameters: {'lambda_l1': 0.000203814997694129, 'lambda_l2': 0.0808272787751168, 'num_leaves': 10, 'feature_fraction': 0.8130189383759407, 'bagging_fraction': 0.41356730179887313, 'bagging_freq': 7, 'min_child_samples': 13}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:49,410] Trial 119 finished with value: 5.047041527560852 and parameters: {'lambda_l1': 0.2708024594637218, 'lambda_l2': 0.39619720453871865, 'num_leaves': 2, 'feature_fraction': 0.7709139842300045, 'bagging_fraction': 0.43748053860734337, 'bagging_freq': 7, 'min_child_samples': 10}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:49,531] Trial 120 finished with value: 6.7608513876674445 and parameters: {'lambda_l1': 2.365872072124661e-05, 'lambda_l2': 0.15273216600254835, 'num_leaves': 19, 'feature_fraction': 0.8792869379626331, 'bagging_fraction': 0.44950775157761336, 'bagging_freq': 7, 'min_child_samples': 51}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:49,686] Trial 121 finished with value: 4.2167030497189835 and parameters: {'lambda_l1': 2.5761968647951213e-06, 'lambda_l2': 0.0426496319151071, 'num_leaves': 22, 'feature_fraction': 0.8553793254567273, 'bagging_fraction': 0.4249837214401801, 'bagging_freq': 7, 'min_child_samples': 7}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:49,865] Trial 122 finished with value: 4.231518430029007 and parameters: {'lambda_l1': 6.821726021860959e-07, 'lambda_l2': 0.079330044151837, 'num_leaves': 28, 'feature_fraction': 0.8492577710728432, 'bagging_fraction': 0.42977692976115367, 'bagging_freq': 7, 'min_child_samples': 7}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:50,036] Trial 123 finished with value: 4.276387098754113 and parameters: {'lambda_l1': 5.505579331924936e-07, 'lambda_l2': 0.24238819381166682, 'num_leaves': 26, 'feature_fraction': 0.6036705964452812, 'bagging_fraction': 0.40275507466583665, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:50,235] Trial 124 finished with value: 4.3034775392202915 and parameters: {'lambda_l1': 1.3077913889237537e-06, 'lambda_l2': 0.032609192177842646, 'num_leaves': 39, 'feature_fraction': 0.8468100038087512, 'bagging_fraction': 0.4625854207559111, 'bagging_freq': 7, 'min_child_samples': 8}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:50,376] Trial 125 finished with value: 4.514012910943459 and parameters: {'lambda_l1': 2.5927459126430076e-06, 'lambda_l2': 0.04833830888399814, 'num_leaves': 29, 'feature_fraction': 0.85587995672917, 'bagging_fraction': 0.43700190848945675, 'bagging_freq': 7, 'min_child_samples': 11}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:50,500] Trial 126 finished with value: 4.269208597045184 and parameters: {'lambda_l1': 1.0175429653672347e-07, 'lambda_l2': 0.11278580581166604, 'num_leaves': 81, 'feature_fraction': 0.8788818544565935, 'bagging_fraction': 0.42630626576623903, 'bagging_freq': 7, 'min_child_samples': 7}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:50,607] Trial 127 finished with value: 4.41392282927981 and parameters: {'lambda_l1': 2.8217897196737947e-07, 'lambda_l2': 0.023584057228819375, 'num_leaves': 49, 'feature_fraction': 0.8703470109301374, 'bagging_fraction': 0.4783096461641435, 'bagging_freq': 4, 'min_child_samples': 13}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:50,730] Trial 128 finished with value: 4.816000275715257 and parameters: {'lambda_l1': 0.0018727688330949783, 'lambda_l2': 0.06492713846499963, 'num_leaves': 15, 'feature_fraction': 0.8870567555257216, 'bagging_fraction': 0.44670125231835683, 'bagging_freq': 7, 'min_child_samples': 16}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:50,870] Trial 129 finished with value: 4.266376889017167 and parameters: {'lambda_l1': 6.666138487575998e-08, 'lambda_l2': 0.9843644309002183, 'num_leaves': 7, 'feature_fraction': 0.8368925049057027, 'bagging_fraction': 0.48712707710701203, 'bagging_freq': 7, 'min_child_samples': 9}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:51,059] Trial 130 finished with value: 4.560857471128675 and parameters: {'lambda_l1': 1.4544344819261662e-06, 'lambda_l2': 1.3469324582720972e-05, 'num_leaves': 32, 'feature_fraction': 0.7016882034389232, 'bagging_fraction': 0.45828212713409794, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:51,192] Trial 131 finished with value: 4.2793022088079695 and parameters: {'lambda_l1': 5.476839230946689e-07, 'lambda_l2': 0.06846557086913053, 'num_leaves': 21, 'feature_fraction': 0.824067706899982, 'bagging_fraction': 0.4154415485343733, 'bagging_freq': 7, 'min_child_samples': 7}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:51,358] Trial 132 finished with value: 4.60651417819709 and parameters: {'lambda_l1': 5.083056453577822e-06, 'lambda_l2': 0.16325428851036855, 'num_leaves': 11, 'feature_fraction': 0.7428994149646306, 'bagging_fraction': 0.42599565211257895, 'bagging_freq': 7, 'min_child_samples': 9}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:51,475] Trial 133 finished with value: 4.266609178812875 and parameters: {'lambda_l1': 2.747284463058706e-07, 'lambda_l2': 0.09467951579527792, 'num_leaves': 18, 'feature_fraction': 0.8557090661700573, 'bagging_fraction': 0.4319450577951297, 'bagging_freq': 7, 'min_child_samples': 7}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:51,580] Trial 134 finished with value: 4.4234241023457015 and parameters: {'lambda_l1': 8.088465565071657e-07, 'lambda_l2': 0.03706795764212699, 'num_leaves': 25, 'feature_fraction': 0.8434757090799085, 'bagging_fraction': 0.41186736704808424, 'bagging_freq': 7, 'min_child_samples': 12}. Best is trial 96 with value: 4.105127894172081.
# [I 2021-12-29 17:33:51,664] Trial 135 finished with value: 4.968691078125365 and parameters: {'lambda_l1': 0.0009205922292366052, 'lambda_l2': 0.2884409145633721, 'num_leaves': 2, 'feature_fraction': 0.897997964996265, 'bagging_fraction': 0.46879781229048856, 'bagging_freq': 2, 'min_child_samples': 5}. Best is trial 96 with value: 4.105127894172081.
# ...
# [I 2021-12-29 17:38:09,407] Trial 956 finished with value: 4.570323970866985 and parameters: {'lambda_l1': 0.17276734617095996, 'lambda_l2': 0.0004754324937966302, 'num_leaves': 142, 'feature_fraction': 0.8115681420442219, 'bagging_fraction': 0.7866296480846398, 'bagging_freq': 7, 'min_child_samples': 8}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:09,629] Trial 957 finished with value: 4.088910652439762 and parameters: {'lambda_l1': 0.09986228155369349, 'lambda_l2': 0.00010013890117256083, 'num_leaves': 135, 'feature_fraction': 0.7964472595807159, 'bagging_fraction': 0.562831139522685, 'bagging_freq': 7, 'min_child_samples': 7}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:09,837] Trial 958 finished with value: 4.512980569043549 and parameters: {'lambda_l1': 0.595004796761329, 'lambda_l2': 0.0002595400266052636, 'num_leaves': 122, 'feature_fraction': 0.8105676289762709, 'bagging_fraction': 0.5999568604182068, 'bagging_freq': 5, 'min_child_samples': 10}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:10,209] Trial 959 finished with value: 4.455469601809766 and parameters: {'lambda_l1': 0.30064157327558194, 'lambda_l2': 0.00013141776019347573, 'num_leaves': 132, 'feature_fraction': 0.793246248367285, 'bagging_fraction': 0.6330069088453293, 'bagging_freq': 7, 'min_child_samples': 13}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:10,577] Trial 960 finished with value: 4.502435489605283 and parameters: {'lambda_l1': 0.6157957105357316, 'lambda_l2': 0.0003705806362079371, 'num_leaves': 235, 'feature_fraction': 0.8217727027935539, 'bagging_fraction': 0.5799425971799962, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:13,409] Trial 961 finished with value: 4.272812175687849 and parameters: {'lambda_l1': 0.38722430622640186, 'lambda_l2': 7.627257390180414e-05, 'num_leaves': 126, 'feature_fraction': 0.7828191435874267, 'bagging_fraction': 0.5624317129048769, 'bagging_freq': 6, 'min_child_samples': 9}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:13,741] Trial 962 finished with value: 4.154510611097453 and parameters: {'lambda_l1': 0.21522771502813465, 'lambda_l2': 0.00015060072460312306, 'num_leaves': 232, 'feature_fraction': 0.8054280009855487, 'bagging_fraction': 0.5751353844435876, 'bagging_freq': 7, 'min_child_samples': 7}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:16,567] Trial 963 finished with value: 4.46378547619804 and parameters: {'lambda_l1': 0.9959566369644924, 'lambda_l2': 5.2876319152937714e-05, 'num_leaves': 106, 'feature_fraction': 0.7335219023198563, 'bagging_fraction': 0.5871479219613931, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:17,269] Trial 964 finished with value: 6.478107565058989 and parameters: {'lambda_l1': 0.5040948551040817, 'lambda_l2': 0.00010175882328580105, 'num_leaves': 94, 'feature_fraction': 0.8190719905262306, 'bagging_fraction': 0.5557235258822943, 'bagging_freq': 7, 'min_child_samples': 52}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:17,472] Trial 965 finished with value: 5.005460829888237 and parameters: {'lambda_l1': 1.7039168401958449, 'lambda_l2': 0.0003036696601028182, 'num_leaves': 124, 'feature_fraction': 0.7146945759455693, 'bagging_fraction': 0.5674036972952208, 'bagging_freq': 7, 'min_child_samples': 24}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:17,622] Trial 966 finished with value: 4.350765940139166 and parameters: {'lambda_l1': 0.15329594242841946, 'lambda_l2': 0.0006306816164488477, 'num_leaves': 147, 'feature_fraction': 0.7579887404182515, 'bagging_fraction': 0.5394275509475724, 'bagging_freq': 7, 'min_child_samples': 8}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:22,524] Trial 967 finished with value: 4.440842449917047 and parameters: {'lambda_l1': 0.766403539507029, 'lambda_l2': 0.00016625664824134584, 'num_leaves': 139, 'feature_fraction': 0.8009530948754682, 'bagging_fraction': 0.5557102405060974, 'bagging_freq': 7, 'min_child_samples': 11}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:22,800] Trial 968 finished with value: 4.303983009586313 and parameters: {'lambda_l1': 0.371804725084207, 'lambda_l2': 0.2594665644975468, 'num_leaves': 118, 'feature_fraction': 0.813117286272445, 'bagging_fraction': 0.5752544000778292, 'bagging_freq': 7, 'min_child_samples': 7}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:22,972] Trial 969 finished with value: 4.227620381349592 and parameters: {'lambda_l1': 0.25846221513129913, 'lambda_l2': 4.0614686621615373e-05, 'num_leaves': 112, 'feature_fraction': 0.827366349012847, 'bagging_fraction': 0.5904347898325857, 'bagging_freq': 7, 'min_child_samples': 9}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:23,153] Trial 970 finished with value: 4.663353977543371 and parameters: {'lambda_l1': 1.0342342808506453, 'lambda_l2': 9.729289030845469e-05, 'num_leaves': 132, 'feature_fraction': 0.527967536824774, 'bagging_fraction': 0.5474341988525667, 'bagging_freq': 7, 'min_child_samples': 15}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:24,421] Trial 971 finished with value: 4.182388792569051 and parameters: {'lambda_l1': 0.03612435440080885, 'lambda_l2': 2.401326112261479e-05, 'num_leaves': 237, 'feature_fraction': 0.7747987838421088, 'bagging_fraction': 0.5645522778993461, 'bagging_freq': 7, 'min_child_samples': 6}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:24,605] Trial 972 finished with value: 4.522600443900089 and parameters: {'lambda_l1': 0.6293929528792644, 'lambda_l2': 0.00025753407898249157, 'num_leaves': 127, 'feature_fraction': 0.7909442330802631, 'bagging_fraction': 0.6081105694335646, 'bagging_freq': 7, 'min_child_samples': 12}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:24,924] Trial 973 finished with value: 4.371958070199948 and parameters: {'lambda_l1': 0.06894885145651163, 'lambda_l2': 0.13844982403431566, 'num_leaves': 102, 'feature_fraction': 0.8058167382305408, 'bagging_fraction': 0.5393975062144025, 'bagging_freq': 7, 'min_child_samples': 10}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:25,209] Trial 974 finished with value: 4.387106455396297 and parameters: {'lambda_l1': 0.26448803586745195, 'lambda_l2': 6.999359387389176e-05, 'num_leaves': 122, 'feature_fraction': 0.821852236464132, 'bagging_fraction': 0.555586421321259, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:25,398] Trial 975 finished with value: 4.363531651597067 and parameters: {'lambda_l1': 0.4447215857259134, 'lambda_l2': 0.00018970870261831864, 'num_leaves': 134, 'feature_fraction': 0.784312884453018, 'bagging_fraction': 0.567229386143513, 'bagging_freq': 7, 'min_child_samples': 8}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:25,584] Trial 976 finished with value: 4.192047218513726 and parameters: {'lambda_l1': 0.15060775730941267, 'lambda_l2': 0.0004080603336523391, 'num_leaves': 239, 'feature_fraction': 0.8280422665879409, 'bagging_fraction': 0.5816432106640886, 'bagging_freq': 7, 'min_child_samples': 7}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:25,796] Trial 977 finished with value: 4.368743669424694 and parameters: {'lambda_l1': 1.309272240051737, 'lambda_l2': 0.00011893107543609482, 'num_leaves': 232, 'feature_fraction': 0.8126682303877341, 'bagging_fraction': 0.5463732492596898, 'bagging_freq': 7, 'min_child_samples': 10}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:26,101] Trial 978 finished with value: 4.3862236381594535 and parameters: {'lambda_l1': 0.6076643931318741, 'lambda_l2': 3.829459142701648e-05, 'num_leaves': 128, 'feature_fraction': 0.8019540798741093, 'bagging_fraction': 0.573094501768318, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:26,242] Trial 979 finished with value: 4.263409186090819 and parameters: {'lambda_l1': 0.3203889024904068, 'lambda_l2': 5.790460709528211e-05, 'num_leaves': 141, 'feature_fraction': 0.79106501850375, 'bagging_fraction': 0.5569809405581863, 'bagging_freq': 7, 'min_child_samples': 8}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:26,467] Trial 980 finished with value: 4.205761435564454 and parameters: {'lambda_l1': 0.002601553707551615, 'lambda_l2': 0.10405636549550486, 'num_leaves': 115, 'feature_fraction': 0.7670910634611472, 'bagging_fraction': 0.5941479805735496, 'bagging_freq': 7, 'min_child_samples': 7}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:26,698] Trial 981 finished with value: 4.236698834387293 and parameters: {'lambda_l1': 0.11056329514859635, 'lambda_l2': 9.098553352655357e-06, 'num_leaves': 120, 'feature_fraction': 0.8324485748858582, 'bagging_fraction': 0.5366547383907185, 'bagging_freq': 7, 'min_child_samples': 9}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:26,845] Trial 982 finished with value: 4.399419216921354 and parameters: {'lambda_l1': 0.8118870447995553, 'lambda_l2': 0.0001798734175014899, 'num_leaves': 193, 'feature_fraction': 0.8136870705960199, 'bagging_fraction': 0.5650599882532473, 'bagging_freq': 7, 'min_child_samples': 12}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:30,362] Trial 983 finished with value: 4.186034898108123 and parameters: {'lambda_l1': 0.19438781837335525, 'lambda_l2': 8.780233552366763e-05, 'num_leaves': 240, 'feature_fraction': 0.7968758675735821, 'bagging_fraction': 0.5489740548894663, 'bagging_freq': 7, 'min_child_samples': 6}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:30,525] Trial 984 finished with value: 4.418777612842844 and parameters: {'lambda_l1': 0.49510376808051515, 'lambda_l2': 0.0003115147692062529, 'num_leaves': 132, 'feature_fraction': 0.8258325427823042, 'bagging_fraction': 0.5740958619659725, 'bagging_freq': 7, 'min_child_samples': 10}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:30,937] Trial 985 finished with value: 4.58171186823612 and parameters: {'lambda_l1': 1.5677480751836912, 'lambda_l2': 2.3133841378994153e-05, 'num_leaves': 125, 'feature_fraction': 0.7790704512129042, 'bagging_fraction': 0.584894865955732, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:31,161] Trial 986 finished with value: 4.5834571218420175 and parameters: {'lambda_l1': 0.8954988352843146, 'lambda_l2': 0.00013207060446172416, 'num_leaves': 108, 'feature_fraction': 0.8137497952125611, 'bagging_fraction': 0.830745951536267, 'bagging_freq': 7, 'min_child_samples': 8}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:31,971] Trial 987 finished with value: 4.190533839294982 and parameters: {'lambda_l1': 0.3240947722244793, 'lambda_l2': 0.17841468172963354, 'num_leaves': 98, 'feature_fraction': 0.8024133387438658, 'bagging_fraction': 0.5539136773930967, 'bagging_freq': 7, 'min_child_samples': 7}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:32,257] Trial 988 finished with value: 4.525048019299954 and parameters: {'lambda_l1': 2.0493846588031652, 'lambda_l2': 0.0007757081956820339, 'num_leaves': 227, 'feature_fraction': 0.8301102282361158, 'bagging_fraction': 0.5645415390912331, 'bagging_freq': 7, 'min_child_samples': 14}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:32,468] Trial 989 finished with value: 4.3500312565360275 and parameters: {'lambda_l1': 0.5563225962798961, 'lambda_l2': 6.0871675711362854e-05, 'num_leaves': 138, 'feature_fraction': 0.7417551366494237, 'bagging_fraction': 0.5390096739494744, 'bagging_freq': 7, 'min_child_samples': 10}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:32,607] Trial 990 finished with value: 5.746549508764072 and parameters: {'lambda_l1': 0.20550585255099824, 'lambda_l2': 0.0002041996607558429, 'num_leaves': 235, 'feature_fraction': 0.8180719175022102, 'bagging_fraction': 0.615768738283768, 'bagging_freq': 7, 'min_child_samples': 42}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:32,910] Trial 991 finished with value: 4.645061680039669 and parameters: {'lambda_l1': 0.999846190060996, 'lambda_l2': 0.10844358880632576, 'num_leaves': 130, 'feature_fraction': 0.7902167266137852, 'bagging_fraction': 0.5784284006076705, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:33,158] Trial 992 finished with value: 4.334519464880475 and parameters: {'lambda_l1': 0.3541648964401879, 'lambda_l2': 1.4156244744790857e-05, 'num_leaves': 242, 'feature_fraction': 0.7640369772842205, 'bagging_fraction': 0.5537559786244334, 'bagging_freq': 6, 'min_child_samples': 9}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:33,381] Trial 993 finished with value: 5.064809525656891 and parameters: {'lambda_l1': 6.533598092569964e-08, 'lambda_l2': 0.00010187765565804954, 'num_leaves': 119, 'feature_fraction': 0.8068285413235194, 'bagging_fraction': 0.6017002944595121, 'bagging_freq': 4, 'min_child_samples': 31}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:33,558] Trial 994 finished with value: 4.763454965878182 and parameters: {'lambda_l1': 0.475760812749852, 'lambda_l2': 0.0004941910544313006, 'num_leaves': 124, 'feature_fraction': 0.8340762774930108, 'bagging_fraction': 0.5622044141812983, 'bagging_freq': 7, 'min_child_samples': 21}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:33,785] Trial 995 finished with value: 4.679045217204151 and parameters: {'lambda_l1': 0.10329796296490655, 'lambda_l2': 0.0001690571952597122, 'num_leaves': 113, 'feature_fraction': 0.8191345557209658, 'bagging_fraction': 0.5406361982045083, 'bagging_freq': 7, 'min_child_samples': 19}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:33,974] Trial 996 finished with value: 4.217885403498398 and parameters: {'lambda_l1': 0.7445769252528808, 'lambda_l2': 3.810866772949849e-05, 'num_leaves': 135, 'feature_fraction': 0.8003709107145737, 'bagging_fraction': 0.5767251515583492, 'bagging_freq': 7, 'min_child_samples': 7}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:34,214] Trial 997 finished with value: 4.344616337554211 and parameters: {'lambda_l1': 0.2198010650736975, 'lambda_l2': 0.0017038247847170583, 'num_leaves': 240, 'feature_fraction': 0.7787842697971189, 'bagging_fraction': 0.5898479683318673, 'bagging_freq': 7, 'min_child_samples': 7}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:34,425] Trial 998 finished with value: 4.356943654722475 and parameters: {'lambda_l1': 1.1954447918356332, 'lambda_l2': 0.0003287875045587088, 'num_leaves': 231, 'feature_fraction': 0.7916810077434747, 'bagging_fraction': 0.5509456060221761, 'bagging_freq': 7, 'min_child_samples': 12}. Best is trial 952 with value: 3.917011523033931.
# [I 2021-12-29 17:38:34,660] Trial 999 finished with value: 4.426754083431567 and parameters: {'lambda_l1': 0.40219880714620293, 'lambda_l2': 0.08593925005772168, 'num_leaves': 180, 'feature_fraction': 0.6647084532131874, 'bagging_fraction': 0.5670427258323769, 'bagging_freq': 7, 'min_child_samples': 9}. Best is trial 952 with value: 3.917011523033931.
# Number of finished trials: 1000
# Best trial:
#   Value: 3.917011523033931
#   Params:
# {'lambda_l1': 0.6174205905201046, 'lambda_l2': 0.0001615654956991066, 'num_leaves': 124, 'feature_fraction': 0.8123750056883934, 'bagging_fraction': 0.562320282799111, 'bagging_freq': 7, 'min_child_samples': 7}

# %%
tuned_params = tuned_params

# %%
tuned_params
# Out:
# {'lambda_l1': 0.6174205905201046,
#  'lambda_l2': 0.0001615654956991066,
#  'num_leaves': 124,
#  'feature_fraction': 0.8123750056883934,
#  'bagging_fraction': 0.562320282799111,
#  'bagging_freq': 7,
#  'min_child_samples': 7}

# %%
valid_socres = []
rmse_list = []
r2_list = []
tuned_models = []
kf = KFold(n_splits=5, shuffle=False)

for fold, (train_index, valid_index) in enumerate(kf.split(X_train)):

    X_tr, X_val = X_train[train_index], X_train[valid_index] 
    y_tr, y_val = y_train[train_index], y_train[valid_index]
    
    trains = lgb.Dataset(data=X_tr, label=y_tr, feature_name='auto') # dataにはテストデータ，labelには正解データ
    evals = lgb.Dataset(data=X_val, label=y_val, feature_name='auto') # feature_name=’auto’とすることで DataFrameの列名が認識される
    
    model = lgb.train(
        tuned_params,
        trains,
        valid_sets=evals,
        num_boost_round=50,
        early_stopping_rounds=10,
        verbose_eval=-1
    )

    pred = model.predict(X_val)
    rmse = np.sqrt(mean_squared_error(y_val, pred))
    r2 = r2_score(y_val, pred)
    rmse_list.append(rmse)
    r2_list.append(r2)
    valid_socres.append(pred)

    tuned_models.append(model)
# Out:
# /home/bi18056/ml/venv/lib/python3.8/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/bi18056/ml/venv/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000054 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 210
# [LightGBM] [Info] Number of data points in the train set: 258, number of used features: 5
# [LightGBM] [Info] Start training from score 22.277907
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Did not meet early stopping. Best iteration is:
# [43]	valid_0's l2: 7.48894
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000062 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 206
# [LightGBM] [Info] Number of data points in the train set: 258, number of used features: 5
# [LightGBM] [Info] Start training from score 22.241473
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Did not meet early stopping. Best iteration is:
# [44]	valid_0's l2: 10.5049
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000049 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 204
# [LightGBM] [Info] Number of data points in the train set: 258, number of used features: 5
# [LightGBM] [Info] Start training from score 21.969768
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Did not meet early stopping. Best iteration is:
# [49]	valid_0's l2: 20.2591
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000130 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 206
# [LightGBM] [Info] Number of data points in the train set: 259, number of used features: 5
# [LightGBM] [Info] Start training from score 21.837838
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /home/bi18056/ml/venv/lib/python3.8/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/bi18056/ml/venv/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/bi18056/ml/venv/lib/python3.8/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/bi18056/ml/venv/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/bi18056/ml/venv/lib/python3.8/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/bi18056/ml/venv/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [29]	valid_0's l2: 6.16443
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000049 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 207
# [LightGBM] [Info] Number of data points in the train set: 259, number of used features: 5
# [LightGBM] [Info] Start training from score 22.127413
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Did not meet early stopping. Best iteration is:
# [50]	valid_0's l2: 12.234
# /home/bi18056/ml/venv/lib/python3.8/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/bi18056/ml/venv/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "

# %%
print(f'rmse: {np.mean(rmse_list)}')
print(f'r2: {np.mean(r2_list)}')
# Out:
# rmse: 3.2918542178979577
# r2: 0.853939630748312

# %%
pred = model.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, pred))
r2 = r2_score(y_test, pred)

print(f'r2: {r2}')
print(f'rmse: {rmse}')
# Out:
# r2: 0.6971544512263478
# rmse: 5.0056123772359875

# %%
trains = lgb.Dataset(data=X_train, label=y_train, feature_name='auto') # dataにはテストデータ，labelには正解データ
evals = lgb.Dataset(data=X_valid, label=y_valid, feature_name='auto') # feature_name=’auto’とすることで DataFrameの列名が認識される
    
model_best = lgb.train(
    tuned_params,
    trains,
    valid_sets=evals,
    num_boost_round=50,
    early_stopping_rounds=10,
    verbose_eval=-1
    )

pred = model_best.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, pred))
r2 = r2_score(y_test, pred)
# Out:
# /home/bi18056/ml/venv/lib/python3.8/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/bi18056/ml/venv/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000055 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 236
# [LightGBM] [Info] Number of data points in the train set: 323, number of used features: 5
# [LightGBM] [Info] Start training from score 22.090712
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Did not meet early stopping. Best iteration is:
# [50]	valid_0's l2: 15.8436

# %%
print(f'rmse: {rmse}')
print(f'r2: {r2}')
# Out:
# rmse: 4.857573945117617
# r2: 0.7148025724093248
